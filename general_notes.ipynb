# %% [markdown]
# # EXPO 48 - SMS
#
# This file is used for general anotations, to-do lists, and whatever else the software team needs.
#
# ## arduino R4 WIFI size (in bytes)
#
# short: 2
# int: 4
# long: 4
# float: 4
# long long: 8
#
# Total Ram: 32kB
# Usable: 24kB
# ## general todo list
#
#
# |module|   to code  |   to test  |
# |---| --- | --- |
# |LCD|  ✓  |  ✓ |
# |buttons|  ✓   |   |
# |PID class|  ✓   |   |
# |temp+humidity sensor|   ✓  |   |
# |peltier element|  not needed   |  ✓ |
# |CO2 sensor| ✓    |   |
# |fan|   not needed  |   |
# |mist disc| not needed |   |
#
# # memory usage
#
# dataLog array is 200kB at max size

# %% [markdown]
# # tasks table
#
#
# |Task Name	|Priority	|Trigger|	Period / Deadline	|Stack Size (Est.)|	Description & Responsibilities|
# |---| --- | --- |--- | --- |--- |
# | dataOutput | || |  ||
# | logData | | | | ||
# |UpdateTargetParameters | | | | ||
# |getSensorData | 1 | | | | returns the current temperature and humidity |
